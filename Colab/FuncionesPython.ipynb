# %%
import pandas as pd
df = pd.read_csv('pandas_practice.csv')

#Mostra la info tecica
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        30 non-null     int64
#  1   order_date      30 non-null     str
#  2   user_id         30 non-null     int64
#  3   user_name       30 non-null     str
#  4   segment         30 non-null     str
#  5   city            30 non-null     str
#  6   state           30 non-null     str
#  7   channel         30 non-null     str
#  8   product         30 non-null     str
#  9   category        30 non-null     str
#  10  quantity        30 non-null     int64
#  11  unit_price      30 non-null     float64
#  12  discount        30 non-null     float64
#  13  returned        30 non-null     bool
#  14  payment_method  30 non-null     str
#  15  gross           30 non-null     float64
#  16  net             30 non-null     float64
# dtypes: bool(1), float64(4), int64(3), str(9)
# ...

# %%
#Mosrar los primeros 6 registros
df.head(6)
# Out:
#    order_id  order_date  user_id user_name    segment    city state channel  \
# 0      1001  2026-01-02        1       Ana   Consumer    CDMX  CDMX     web
# 1      1002  2026-01-02        2      Luis  Corporate     GDL   JAL   store
# 2      1003  2026-01-03        3     Marta   Consumer     MTY    NL     web
# 3      1004  2026-01-03        4     Jorge  Small Biz    CDMX  CDMX     app
# 4      1005  2026-01-04        1       Ana   Consumer  Puebla   PUE     web
# 5      1006  2026-01-05        5     Sofia  Corporate     QRO   QRO   store
#
#           product     category  quantity  unit_price  discount  returned  \
# 0   Laptop Sleeve  Accessories         1        35.0      0.10     False
# 1  Wireless Mouse  Accessories         2        18.5      0.00     False
# 2        Keyboard  Accessories         1        45.0      0.05      True
# 3     Monitor 24"  Electronics         1       160.0      0.15     False
# ...

# %%
#Mostrar los 6 ultimos
df.tail(6)
# Out:
#     order_id  order_date  user_id user_name    segment    city state channel  \
# 24      1025  2026-01-17        7     Karla  Small Biz     MTY    NL     web
# 25      1026  2026-01-17        8     Pedro   Consumer    CDMX  CDMX     app
# 26      1027  2026-01-18        4     Jorge  Small Biz    CDMX  CDMX     web
# 27      1028  2026-01-18       12      Hugo  Corporate     MTY    NL   store
# 28      1029  2026-01-19        1       Ana   Consumer  Puebla   PUE     app
# 29      1030  2026-01-20       13      Nora  Small Biz  Puebla   PUE     web
#
#             product     category  quantity  unit_price  discount  returned  \
# 24           Router  Electronics         1       130.0      0.20     False
# 25     Sticky Notes   Stationery         6         1.5      0.00     False
# 26       USB-C Dock  Electronics         1       175.0      0.10     False
# 27    Ink Cartridge   Stationery         2        25.0      0.00     False
# ...

# %% [markdown]
# Funcion .loc

# %%
#seleccionar la columna "user_name"
#sintaxis df.loc[fila,columna]
df.loc[:,'user_name']
# Out:
# 0       Ana
# 1      Luis
# 2     Marta
# 3     Jorge
# 4       Ana
# 5     Sofia
# 6     Diego
# 7     Karla
# 8     Pedro
# 9      Luis
# 10    Elena
# 11    Marta
# 12    Ramon
# 13    Paula
# 14     Hugo
# 15    Diego
# 16    Sofia
# 17     Nora
# 18     Ivan
# 19    Lucia
# 20    Elena
# 21    Paula
# 22    Ramon
# 23     Luis
# 24    Karla
# 25    Pedro
# 26    Jorge
# 27     Hugo
# 28      Ana
# 29     Nora
# Name: user_name, dtype: str

# %%
#mostar el registro de la fila 2
df.loc[1,:]
# Out:
# order_id                    1002
# order_date            2026-01-02
# user_id                        2
# user_name                   Luis
# segment                Corporate
# city                         GDL
# state                        JAL
# channel                    store
# product           Wireless Mouse
# category             Accessories
# quantity                       2
# unit_price                  18.5
# discount                     0.0
# returned                   False
# payment_method              cash
# gross                       37.0
# net                         37.0
# Name: 1, dtype: object

# %%
#Mostrar_name, prodcut, order_id, oder_data
df.loc[:,["order_id","user_name","product", "order_date"]]
# Out:
#     order_id user_name            product  order_date
# 0       1001       Ana      Laptop Sleeve  2026-01-02
# 1       1002      Luis     Wireless Mouse  2026-01-02
# 2       1003     Marta           Keyboard  2026-01-03
# 3       1004     Jorge        Monitor 24"  2026-01-03
# 4       1005       Ana        USB-C Cable  2026-01-04
# 5       1006     Sofia       Office Chair  2026-01-05
# 6       1007     Diego          Desk Lamp  2026-01-05
# 7       1008     Karla            SSD 1TB  2026-01-06
# 8       1009     Pedro           Notebook  2026-01-06
# 9       1010      Luis        Monitor 27"  2026-01-07
# 10      1011     Elena            Pen Set  2026-01-07
# 11      1012     Marta             Webcam  2026-01-08
# 12      1013     Ramon      Standing Desk  2026-01-09
# 13      1014     Paula         Headphones  2026-01-09
# 14      1015      Hugo         Paper Ream  2026-01-10
# 15      1016     Diego            USB Hub  2026-01-10
# ...

# %%
_#Filtrar con una  condicion y elegir las columnas
df.loc[df["city"] == "CDMX", ["order_id","user_name","product", "order_date","payment_method","city"]]
# Out:
#     order_id user_name           product  order_date payment_method  city
# 0       1001       Ana     Laptop Sleeve  2026-01-02           card  CDMX
# 3       1004     Jorge       Monitor 24"  2026-01-03           card  CDMX
# 8       1009     Pedro          Notebook  2026-01-06           cash  CDMX
# 12      1013     Ramon     Standing Desk  2026-01-09       transfer  CDMX
# 18      1019      Ivan  Smartphone Stand  2026-01-12           card  CDMX
# 22      1023     Ramon         Floor Mat  2026-01-15           cash  CDMX
# 25      1026     Pedro      Sticky Notes  2026-01-17           cash  CDMX
# 26      1027     Jorge        USB-C Dock  2026-01-18           card  CDMX

# %%
#Filtar con varias condiciones
#"category","discount"
#category = electronico y descuent mayr a 10, id descunto metodo y categoria
x = (df["category"] == "Electronics") & (df["discount"] > 0.10) 
df.loc[x, ["order_id","product", "discount", "payment_method", "category"]]
# Out:
#     order_id        product  discount payment_method     category
# 3       1004    Monitor 24"      0.15           card  Electronics
# 16      1017  Ergo Keyboard      0.15           card  Electronics
# 24      1025         Router      0.20           card  Electronics

# %% [markdown]
# Funcion .iloc

# %%
#mostrar la columna üser_name"utilizando iloc
#sintaxis df.iloc[fila,columna]
df.iloc[:,3]

# %%
#mostar filas especificas, 0-5
df.iloc[0:5]
# Out:
#    order_id  order_date  user_id user_name    segment    city state channel  \
# 0      1001  2026-01-02        1       Ana   Consumer    CDMX  CDMX     web
# 1      1002  2026-01-02        2      Luis  Corporate     GDL   JAL   store
# 2      1003  2026-01-03        3     Marta   Consumer     MTY    NL     web
# 3      1004  2026-01-03        4     Jorge  Small Biz    CDMX  CDMX     app
# 4      1005  2026-01-04        1       Ana   Consumer  Puebla   PUE     web
#
#           product     category  quantity  unit_price  discount  returned  \
# 0   Laptop Sleeve  Accessories         1        35.0      0.10     False
# 1  Wireless Mouse  Accessories         2        18.5      0.00     False
# 2        Keyboard  Accessories         1        45.0      0.05      True
# 3     Monitor 24"  Electronics         1       160.0      0.15     False
# 4     USB-C Cable  Accessories         3         8.0      0.00     False
#
#   payment_method  gross     net
# 0           card   35.0   31.50
# ...

# %%
#Mostar fila 0, 3 y 6
df.iloc[[0,3,6]]
# Out:
#    order_id  order_date  user_id user_name    segment  city state channel  \
# 0      1001  2026-01-02        1       Ana   Consumer  CDMX  CDMX     web
# 3      1004  2026-01-03        4     Jorge  Small Biz  CDMX  CDMX     app
# 6      1007  2026-01-05        6     Diego   Consumer   GDL   JAL     web
#
#          product     category  quantity  unit_price  discount  returned  \
# 0  Laptop Sleeve  Accessories         1        35.0      0.10     False
# 3    Monitor 24"  Electronics         1       160.0      0.15     False
# 6      Desk Lamp    Furniture         2        28.0      0.00      True
#
#   payment_method  gross    net
# 0           card   35.0   31.5
# 3           card  160.0  136.0
# 6           card   56.0   56.0

# %%
#Mostrar las primeras 5 filas y 4 columnas
df.iloc[0:5,0:4]
# Out:
#    order_id  order_date  user_id user_name
# 0      1001  2026-01-02        1       Ana
# 1      1002  2026-01-02        2      Luis
# 2      1003  2026-01-03        3     Marta
# 3      1004  2026-01-03        4     Jorge
# 4      1005  2026-01-04        1       Ana

# %% [markdown]
# Query

# %%
#cONSULTA SIMPLE
#Mostar todos los registros de CDMX
df.query("city == 'CDMX'")
# Out:
#     order_id  order_date  user_id user_name    segment  city state channel  \
# 0       1001  2026-01-02        1       Ana   Consumer  CDMX  CDMX     web
# 3       1004  2026-01-03        4     Jorge  Small Biz  CDMX  CDMX     app
# 8       1009  2026-01-06        8     Pedro   Consumer  CDMX  CDMX   store
# 12      1013  2026-01-09       10     Ramon  Small Biz  CDMX  CDMX   store
# 18      1019  2026-01-12       14      Ivan   Consumer  CDMX  CDMX     web
# 22      1023  2026-01-15       10     Ramon  Small Biz  CDMX  CDMX     web
# 25      1026  2026-01-17        8     Pedro   Consumer  CDMX  CDMX     app
# 26      1027  2026-01-18        4     Jorge  Small Biz  CDMX  CDMX     web
#
#              product     category  quantity  unit_price  discount  returned  \
# 0      Laptop Sleeve  Accessories         1        35.0      0.10     False
# 3        Monitor 24"  Electronics         1       160.0      0.15     False
# ...

# %%
#Mostar los registros que sean de CDMX, electronicos y con un descuento igual a .1
df.query("city=='CDMX' & category == 'Electronics' & discount == 0.1")
# Out:
#     order_id  order_date  user_id user_name    segment  city state channel  \
# 26      1027  2026-01-18        4     Jorge  Small Biz  CDMX  CDMX     web
#
#        product     category  quantity  unit_price  discount  returned  \
# 26  USB-C Dock  Electronics         1       175.0       0.1     False
#
#    payment_method  gross    net
# 26           card  175.0  157.5

# %%
#Mostar los registros que sea de CDMX,GDL, con un descuento iguak a .1
dis = 0.1
ciudades = ["CDMX", "GDL"]
df.query("discount == @dis and city in @ciudades")
# Out:
#     order_id  order_date  user_id user_name    segment  city state channel  \
# 0       1001  2026-01-02        1       Ana   Consumer  CDMX  CDMX     web
# 12      1013  2026-01-09       10     Ramon  Small Biz  CDMX  CDMX   store
# 18      1019  2026-01-12       14      Ivan   Consumer  CDMX  CDMX     web
# 21      1022  2026-01-15       11     Paula   Consumer   GDL   JAL     app
# 26      1027  2026-01-18        4     Jorge  Small Biz  CDMX  CDMX     web
#
#               product     category  quantity  unit_price  discount  returned  \
# 0       Laptop Sleeve  Accessories         1        35.0       0.1     False
# 12      Standing Desk    Furniture         1       420.0       0.1     False
# 18   Smartphone Stand  Accessories         2        14.0       0.1     False
# 21  Bluetooth Speaker  Electronics         1        80.0       0.1     False
# 26         USB-C Dock  Electronics         1       175.0       0.1     False
#
#    payment_method  gross    net
# ...

# %% [markdown]
# **Agregacion**
# .sum()
# .mean()
# .median()
# .count()
# .min()
# .max()

# %%
df["net"].sum()
# Out:
# np.float64(2336.95)

# %%
df["net"].mean()
# Out:
# np.float64(77.89833333333333)

# %%
df["net"].median()
# Out:
# np.float64(46.375)

# %%
df["net"].count()
# Out:
# np.int64(30)

# %%
df["net"].count()
# Out:
# np.int64(30)

# %%
df["net"].min(), df["net"].max()
# Out:
# (np.float64(9.0), np.float64(378.0))

# %%
#Aplicamob las funcione suma, media , minimo, y maximo a las columnas "unit_price" , "net"
df[["unit_price", "net"]].agg(["sum","mean","min","max"])
# Out:
#       unit_price          net
# sum       2415.0  2336.950000
# mean        80.5    77.898333
# min          1.5     9.000000
# max        420.0   378.000000

# %%
#Diferetbtes funciones

df.agg({
    "net": ["sum","mean"],
    "unit_price": ["max","min"],
    "discount": ["mean","max"]
})
# Out:
#               net  unit_price  discount
# sum   2336.950000         NaN       NaN
# mean    77.898333         NaN  0.056667
# max           NaN       420.0  0.200000
# min           NaN         1.5       NaN

# %%
g = df.groupby("city")
#ver que grupos rxisten
g.groups.keys()
# Out:
# dict_keys(['CDMX', 'GDL', 'MTY', 'Mérida', 'Puebla', 'QRO'])

# %%
g.ngroups
# Out:
# 6

# %%
# Agrupar por varias columnas (corrige paréntesis y nombre de columna)
g2 = df.groupby(["state", "channel"])
g2.groups.keys()
# Out:
# dict_keys([('CDMX', 'app'), ('CDMX', 'store'), ('CDMX', 'web'), ('JAL', 'app'), ('JAL', 'store'), ('JAL', 'web'), ('NL', 'app'), ('NL', 'store'), ('NL', 'web'), ('PUE', 'app'), ('PUE', 'web'), ('QRO', 'store'), ('QRO', 'web'), ('YUC', 'app'), ('YUC', 'web')])

# %%
#Ventas por ciudad
df.groupby("city"["net"].agg(["sum","mean","min","max"]))

# %%
#Varias Metricas
df.groupby("category").agg(
    net_sum = ("net" , "sum"),
    net_mean = ("net", "mean"),
    orders = ("order_id", "nunique"),
     discount_mean = ("discount", "mean"),


)

# %%
#orden por columna (des)
df_sorted =df.sort_values("net", ascending=False)
df_sorted.head()

# %%
df_sorted =df.sort_values(["net","unit_price"], ascending=[False,True])
df_sorted.head()
# Out:
#     order_id  order_date  user_id user_name    segment    city state channel  \
# 12      1013  2026-01-09       10     Ramon  Small Biz    CDMX  CDMX   store
# 9       1010  2026-01-07        2      Luis  Corporate     GDL   JAL     web
# 29      1030  2026-01-20       13      Nora  Small Biz  Puebla   PUE     web
# 5       1006  2026-01-05        5     Sofia  Corporate     QRO   QRO   store
# 26      1027  2026-01-18        4     Jorge  Small Biz    CDMX  CDMX     web
#
#            product     category  quantity  unit_price  discount  returned  \
# 12   Standing Desk    Furniture         1       420.0      0.10     False
# 9      Monitor 27"  Electronics         1       240.0      0.05     False
# 29  Filing Cabinet    Furniture         1       260.0      0.15     False
# 5     Office Chair    Furniture         1       220.0      0.20     False
# 26      USB-C Dock  Electronics         1       175.0      0.10     False
#
#    payment_method  gross    net
# ...

# %%
df2 = df.set_index("order_date")
df2 = df.sort_index()
df2.head()
# Out:
#    order_id  order_date  user_id user_name    segment    city state channel  \
# 0      1001  2026-01-02        1       Ana   Consumer    CDMX  CDMX     web
# 1      1002  2026-01-02        2      Luis  Corporate     GDL   JAL   store
# 2      1003  2026-01-03        3     Marta   Consumer     MTY    NL     web
# 3      1004  2026-01-03        4     Jorge  Small Biz    CDMX  CDMX     app
# 4      1005  2026-01-04        1       Ana   Consumer  Puebla   PUE     web
#
#           product     category  quantity  unit_price  discount  returned  \
# 0   Laptop Sleeve  Accessories         1        35.0      0.10     False
# 1  Wireless Mouse  Accessories         2        18.5      0.00     False
# 2        Keyboard  Accessories         1        45.0      0.05      True
# 3     Monitor 24"  Electronics         1       160.0      0.15     False
# 4     USB-C Cable  Accessories         3         8.0      0.00     False
#
#   payment_method  gross     net
# 0           card   35.0   31.50
# ...

# %%
df_cols_sorted = df.sort_index(axis=1)
df_cols_sorted.head()
# Out:
#       category channel    city  discount  gross     net  order_date  order_id  \
# 0  Accessories     web    CDMX      0.10   35.0   31.50  2026-01-02      1001
# 1  Accessories   store     GDL      0.00   37.0   37.00  2026-01-02      1002
# 2  Accessories     web     MTY      0.05   45.0   42.75  2026-01-03      1003
# 3  Electronics     app    CDMX      0.15  160.0  136.00  2026-01-03      1004
# 4  Accessories     web  Puebla      0.00   24.0   24.00  2026-01-04      1005
#
#   payment_method         product  quantity  returned    segment state  \
# 0           card   Laptop Sleeve         1     False   Consumer  CDMX
# 1           cash  Wireless Mouse         2     False  Corporate   JAL
# 2           card        Keyboard         1      True   Consumer    NL
# 3           card     Monitor 24"         1     False  Small Biz  CDMX
# 4       transfer     USB-C Cable         3     False   Consumer   PUE
#
#    unit_price  user_id user_name
# 0        35.0        1       Ana
# ...

# %% [markdown]
# **Funcion Merge**

# %%
df.info()

# %%
# Vamos a crear una nueva tabla de usuarios únicos
users = df[["user_id", "user_name", "segment"]].drop_duplicates("user_id")
users.head()
# Out:
#    user_id user_name    segment
# 0        1       Ana   Consumer
# 1        2      Luis  Corporate
# 2        3     Marta   Consumer
# 3        4     Jorge  Small Biz
# 5        5     Sofia  Corporate

# %%
df1 = df.merge(users, on="user_id", how="left", suffixes=("", "_user"), validate="many_to_one")
df1.head()
# Out:
#    order_id  order_date  user_id user_name    segment    city state channel  \
# 0      1001  2026-01-02        1       Ana   Consumer    CDMX  CDMX     web
# 1      1002  2026-01-02        2      Luis  Corporate     GDL   JAL   store
# 2      1003  2026-01-03        3     Marta   Consumer     MTY    NL     web
# 3      1004  2026-01-03        4     Jorge  Small Biz    CDMX  CDMX     app
# 4      1005  2026-01-04        1       Ana   Consumer  Puebla   PUE     web
#
#           product     category  quantity  unit_price  discount  returned  \
# 0   Laptop Sleeve  Accessories         1        35.0      0.10     False
# 1  Wireless Mouse  Accessories         2        18.5      0.00     False
# 2        Keyboard  Accessories         1        45.0      0.05      True
# 3     Monitor 24"  Electronics         1       160.0      0.15     False
# 4     USB-C Cable  Accessories         3         8.0      0.00     False
#
#   payment_method  gross     net user_name_user segment_user
# ...

# %%
a = df.iloc[:10]
b = df.iloc[10:]

reconstruido = pd.concat([a,b], ignore_index=True)
reconstruido
# Out:
#     order_id  order_date  user_id user_name    segment    city state channel  \
# 0       1001  2026-01-02        1       Ana   Consumer    CDMX  CDMX     web
# 1       1002  2026-01-02        2      Luis  Corporate     GDL   JAL   store
# 2       1003  2026-01-03        3     Marta   Consumer     MTY    NL     web
# 3       1004  2026-01-03        4     Jorge  Small Biz    CDMX  CDMX     app
# 4       1005  2026-01-04        1       Ana   Consumer  Puebla   PUE     web
# 5       1006  2026-01-05        5     Sofia  Corporate     QRO   QRO   store
# 6       1007  2026-01-05        6     Diego   Consumer     GDL   JAL     web
# 7       1008  2026-01-06        7     Karla  Small Biz     MTY    NL     app
# 8       1009  2026-01-06        8     Pedro   Consumer    CDMX  CDMX   store
# 9       1010  2026-01-07        2      Luis  Corporate     GDL   JAL     web
# 10      1011  2026-01-07        9     Elena   Consumer  Mérida   YUC     app
# ...
